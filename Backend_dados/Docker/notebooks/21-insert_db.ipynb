# %%
import pandas as pd
import os
import sys
import importlib
import utils.conexao
importlib.reload(utils.conexao)
# Adiciona o diretório-raiz do projeto ao sys.path
sys.path.append('/app')

from utils.conexao import salvar_dados_destino, adicionar_chave_primaria, adicionar_chave_estrangeira

# %% [markdown]
# ### *Colaborador*

# %%
# variável de ambiente para construir o caminho
caminho_base = os.environ.get("CAMINHO_ARQUIVOS_CSV")
caminho_completo = os.path.join(caminho_base, "dados_tratados_v2", "dc_DadosPrimarios_tratado.csv")

df = pd.read_csv(caminho_completo)


# salvar o DataFrame no banco de dados.
# cria a tabela 'servico_competencia' no schema de destino.
salvar_dados_destino(df, 'colaborador')
# Adiciona a chave primária

# %% [markdown]
# ### *Cidades*

# %%
# Caminho do arquivo
caminho_base = os.environ.get("CAMINHO_ARQUIVOS_CSV")
caminho_completo = os.path.join(caminho_base, "dados_tratados_v2", "dim_Cidades.csv")

df = pd.read_csv(caminho_completo)
df['idCidade'] = df['idCidade'].astype(int)

# Salva os dados tratados na tabela 'cidade'
salvar_dados_destino(df, 'cidade')


print("Tabela 'cidade' criada com sucesso")

# %% [markdown]
# ### *Certificacao*

# %%
# Caminho do arquivo

caminho_base = os.environ.get("CAMINHO_ARQUIVOS_CSV")
caminho_completo = os.path.join(caminho_base, "dados_tratados_v2", "dim_Certificacao.csv")

df = pd.read_csv(caminho_completo)

# Salva os dados tratados na tabela 'certificacao'
salvar_dados_destino(df, 'certificacao')




print("Tabela 'Certificacao' criada com sucesso.")

# %% [markdown]
# ### *Formacao*

# %%
# Caminho do arquivo

caminho_base = os.environ.get("CAMINHO_ARQUIVOS_CSV")
caminho_completo = os.path.join(caminho_base, "dados_tratados_v2", "dim_Formacao.csv")

df = pd.read_csv(caminho_completo)

# Salva os dados tratados na tabela 'formacao_academica'
salvar_dados_destino(df, 'formacao_academica')



print("Tabela 'formacao' criada com sucesso.")

# %% [markdown]
# ### *Softskills*

# %%
# Caminho do arquivo

caminho_base = os.environ.get("CAMINHO_ARQUIVOS_CSV")
caminho_completo = os.path.join(caminho_base, "dados_tratados_v2", "dim_Softskills.csv")

df = pd.read_csv(caminho_completo)

# Salva os dados tratados na tabela 'softskills'
salvar_dados_destino(df, 'softskills')


print("Tabela 'softskills' criada com sucesso.")

# %% [markdown]
# ### *Treinamentos*

# %%
# Caminho do arquivo

caminho_base = os.environ.get("CAMINHO_ARQUIVOS_CSV")
caminho_completo = os.path.join(caminho_base, "dados_tratados_v2", "dim_Treinamentos.csv")

df = pd.read_csv(caminho_completo)

# Salva os dados tratados na tabela 'treinamentos'
salvar_dados_destino(df, 'treinamentos')


print("Tabela 'treinamentos' criada com sucesso")

# %% [markdown]
# ### *Competencia*

# %%
# Caminho do arquivo
caminho_base = os.environ.get("CAMINHO_ARQUIVOS_CSV")
caminho_completo = os.path.join(caminho_base, "dados_tratados_v2", "competencia_postgres_tratado.csv")

df = pd.read_csv(caminho_completo)

# Salva os dados tratados na tabela 'competencia'
salvar_dados_destino(df, 'competencia')

print("Tabela 'competencia' criada com sucesso, com chave primária .")

# %% [markdown]
# ### *Servico*

# %%
# Caminho do arquivo

caminho_base = os.environ.get("CAMINHO_ARQUIVOS_CSV")
caminho_completo = os.path.join(caminho_base, "dados_tratados_v2", "servicos_postgres_tratado.csv")

df = pd.read_csv(caminho_completo)

# Salva os dados tratados na tabela 'servicos'
salvar_dados_destino(df, 'servicos')


print("Tabela 'servicos' criada com sucesso")

# %% [markdown]
# ### *Empresa*

# %%
# Caminho do arquivo

caminho_base = os.environ.get("CAMINHO_ARQUIVOS_CSV")
caminho_completo = os.path.join(caminho_base, "dados_tratados_v2", "empresa_postgres_tratado.csv")

df = pd.read_csv(caminho_completo)

# Salva os dados tratados na tabela 'empresa'
salvar_dados_destino(df, 'empresa')



print("Tabela 'empresa' criada com sucesso.")

# %% [markdown]
# ### *data_admissao*

# %%
# variável de ambiente para construir o caminho
caminho_base = os.environ.get("CAMINHO_ARQUIVOS_CSV")
caminho_completo = os.path.join(caminho_base, "dados_tratados_v2", "dc_DataAdmissao_Tratado.csv")

df_admissao = pd.read_csv(caminho_completo)

salvar_dados_destino(df_admissao, 'data_admissao')

# %% [markdown]
# ### *colaborador_photo*

# %% [markdown]
# ### *colaborador_Certificacao*

# %%
caminho_base = os.environ.get("CAMINHO_ARQUIVOS_CSV")
caminho_completo = os.path.join(caminho_base, "dados_tratados_v2", "fato_Certificacao.csv")

df = pd.read_csv(caminho_completo)

# salvar o DataFrame no banco de dados.
# cria a tabela 'colabotador_certificacao' no schema de destino.
salvar_dados_destino(df, 'colaborador_certificacao')

# %% [markdown]
# ### *colaborador_Formacao*

# %%
# Caminho do arquivo

caminho_base = os.environ.get("CAMINHO_ARQUIVOS_CSV")
caminho_completo = os.path.join(caminho_base, "dados_tratados_v2", "fato_Formacao.csv")

df = pd.read_csv(caminho_completo)

# salvar o DataFrame no banco de dados.
# cria a tabela 'colaboraodr_formacao' no schema de destino.
salvar_dados_destino(df, 'colaborador_formacao')

# %% [markdown]
# ### *colaborador_treinamentos*

# %%
# Caminho do arquivo

caminho_base = os.environ.get("CAMINHO_ARQUIVOS_CSV")
caminho_completo = os.path.join(caminho_base, "dados_tratados_v2", "fato_Treinamentos.csv")

df = pd.read_csv(caminho_completo)
# salvar o DataFrame no banco de dados.
# cria a tabela 'colaborador_treinamentos' no schema de destino.
salvar_dados_destino(df, 'colaborador_treinamentos')

# %% [markdown]
# ### *colaborador_softskills*

# %%
# Caminho do arquivo

caminho_base = os.environ.get("CAMINHO_ARQUIVOS_CSV")
caminho_completo = os.path.join(caminho_base, "dados_tratados_v2", "fato_Softskills.csv")

df = pd.read_csv(caminho_completo)

# salvar o DataFrame no banco de dados.
# cria a tabela 'colaborador_softskills' no schema de destino.
salvar_dados_destino(df, 'colaborador_softskills')

# %% [markdown]
# ### *colaborador_empresa*

# %%
# Caminho do arquivo
caminho_base = os.environ.get("CAMINHO_ARQUIVOS_CSV")
caminho_completo = os.path.join(caminho_base, "dados_tratados_v2", "colaborador_empresa_postgres_tratado.csv")

df = pd.read_csv(caminho_completo)


# salvar o  DataFrame no banco de dados.
# cria tabela 'colaborador_empresa' no schema de destino.
salvar_dados_destino(df, 'colaborador_empresa')

# %% [markdown]
# ### *empresa_servico*

# %%
# Caminho do arquivo
caminho_base = os.environ.get("CAMINHO_ARQUIVOS_CSV")
caminho_completo = os.path.join(caminho_base, "dados_tratados_v2", "fato_Empresa_Servico.csv")

df = pd.read_csv(caminho_completo)

# salvar o  DataFrame no banco de dados.
salvar_dados_destino(df, 'empresa_servico')

# %% [markdown]
# ### *servico_competencia*

# %%
# Caminho do arquivo
caminho_base = os.environ.get("CAMINHO_ARQUIVOS_CSV")
caminho_completo = os.path.join(caminho_base, "dados_tratados_v2", "fato_servico_competencia.csv")

df = pd.read_csv(caminho_completo)

salvar_dados_destino(df, 'servico_competencia')

# %%
# Caminho do arquivo
caminho_base = os.environ.get("CAMINHO_ARQUIVOS_CSV")
caminho_completo = os.path.join(caminho_base, "dados_tratados_v2", "fato_colaborador_competencia.csv")

df = pd.read_csv(caminho_completo)
# cria a tabela 'colaborador_competencia' no schema de destino.
salvar_dados_destino(df, 'colaborador_competencia')

# %% [markdown]
# # *chave primaria*

# %% [markdown]
# colaborador

# %%
adicionar_chave_primaria('colaborador', ['idColaborador'])# Caminho do arquivo

# %% [markdown]
# cidade

# %%
# Adiciona a chave primária
adicionar_chave_primaria('cidade', ['idCidade'])

# %% [markdown]
# certificacao

# %%
# Adiciona a chave primária
adicionar_chave_primaria('certificacao', ['idCertificacao'])

# %% [markdown]
# formacao

# %%
# Adiciona a chave primária
adicionar_chave_primaria('formacao_academica', ['idFormacao_Academica'])

# %% [markdown]
# softskills

# %%
# Adiciona a chave primária
adicionar_chave_primaria('softskills', ['idSoft_Skills'])

# %% [markdown]
# treinamentos

# %%
# Adiciona a chave primária
adicionar_chave_primaria('treinamentos', ['idTreinamentos_Realizados'])

# %% [markdown]
# competencia

# %%
# Adiciona a chave primária
adicionar_chave_primaria('competencia', ['Id_Competencia'])

# %% [markdown]
# servicos

# %%
# Adiciona a chave primária
adicionar_chave_primaria('servicos', ['Id_Servico'])

# %% [markdown]
# empresa

# %%
# Adiciona a chave primária
adicionar_chave_primaria('empresa', ['Id_Empresa'])

# %% [markdown]
# colaborador_certificacao

# %%
# Adiciona a chave primária
adicionar_chave_primaria('colaborador_certificacao', ['idColaborador', 'idCertificacao'])

# %% [markdown]
# colaborador_formacao

# %%
# Adiciona a chave primária
adicionar_chave_primaria('colaborador_formacao', ['idColaborador', 'idFormacao_Academica'])

# %% [markdown]
# colaborador_treinamentos

# %%
# Adiciona a chave primária composta
adicionar_chave_primaria('colaborador_treinamentos', ['idColaborador', 'idTreinamentos_Realizados'])

# %% [markdown]
# colaborador_softskills

# %%
# define a chave primária composta da tabela 'colaborador_softskills'.
adicionar_chave_primaria('colaborador_softskills', ['idColaborador', 'idSoft_Skills'])

# %% [markdown]
# colaborador_empresa

# %%
# Adiciona a chave primária
adicionar_chave_primaria('colaborador_empresa', ['idColaborador', 'Id_Empresa'])

# %% [markdown]
# data admissao

# %%
# define a chave primária da tabela 'data_admissao'.
adicionar_chave_primaria('data_admissao', ['idData_Admissao'])

# %% [markdown]
# colaborador_photo

# %% [markdown]
# empresa servico

# %%
# Adiciona a chave primária
adicionar_chave_primaria('empresa_servico', ['Id_Empresa', 'Id_Servico'])

# %% [markdown]
# servico_competencia

# %%
adicionar_chave_primaria('servico_competencia', ['Id_Servico', 'Id_Competencia'])

# %% [markdown]
# colaborador competencia

# %%
# adiciona a chave primária na tabela 'colaborador_competencia'
adicionar_chave_primaria('colaborador_competencia', ['id'])

# %% [markdown]
# # chave estrangeira

# %% [markdown]
# colaborador

# %%
# Define a primeira chave estrangeira (FK).
adicionar_chave_estrangeira(
    tabela_origem='colaborador',    # Tabela onde adiciona FK
    coluna_origem='idCidade',             # Coluna na tabela que é a FK
    tabela_destino='cidade',               # Tabela que a FK referencia
    coluna_destino='idCidade'             # Coluna na tabela de destino
)


# Define a segunda chave estrangeira (FK)
adicionar_chave_estrangeira(
    tabela_origem='colaborador',    
    coluna_origem='idData_Admissao',         
    tabela_destino='data_admissao',           
    coluna_destino='idData_Admissao'         
)

# %% [markdown]
# pcd

# %%
# Define a primeira chave estrangeira (FK).
adicionar_chave_estrangeira(
    tabela_origem='PCD',    # Tabela onde adiciona a FK
    coluna_origem='idColaborador', # Coluna na tabela que é a FK
    tabela_destino='colaborador',  # Tabela que a FK referencia
    coluna_destino='idColaborador' # Coluna na tabela de destino
)

# %% [markdown]
# Colaborador_certificacao

# %%
# Define a primeira chave estrangeira (FK).
adicionar_chave_estrangeira(
    tabela_origem='colaborador_certificacao',    
    coluna_origem='idColaborador',            
    tabela_destino='colaborador',               
    coluna_destino='idColaborador'             
)


# Define a segunda chave estrangeira (FK)
adicionar_chave_estrangeira(
    tabela_origem='colaborador_certificacao',    
    coluna_origem='idCertificacao',        
    tabela_destino='certificacao',           
    coluna_destino='idCertificacao'        
)

# %% [markdown]
# ### *Colaborador_formacao*

# %%
# Define a primeira chave estrangeira (FK).
adicionar_chave_estrangeira(
    tabela_origem='colaborador_formacao',    
    coluna_origem='idColaborador',             
    tabela_destino='colaborador',               
    coluna_destino='idColaborador'             
)

# Define a segunda chave estrangeira (FK)
adicionar_chave_estrangeira(
    tabela_origem='colaborador_formacao',    
    coluna_origem='idFormacao_Academica',         
    tabela_destino='formacao_academica',           
    coluna_destino='idFormacao_Academica'         
)

# %% [markdown]
# ### *Colaborador_softskills*

# %%
# Define a primeira chave estrangeira (FK).
adicionar_chave_estrangeira(
    tabela_origem='colaborador_softskills',    
    coluna_origem='idColaborador',            
    tabela_destino='colaborador',               
    coluna_destino='idColaborador'             
)


# Define a segunda chave estrangeira (FK)
adicionar_chave_estrangeira(
    tabela_origem='colaborador_softskills',    
    coluna_origem='idSoft_Skills',         
    tabela_destino='softskills',           
    coluna_destino='idSoft_Skills'         
)

# %% [markdown]
# ### *Colaborador_treinamentos*

# %%
# Define a primeira chave estrangeira (FK).
adicionar_chave_estrangeira(
    tabela_origem='colaborador_treinamentos',
    coluna_origem='idColaborador',             
    tabela_destino='colaborador',               
    coluna_destino='idColaborador'             
)

# Define a segunda chave estrangeira (FK)
adicionar_chave_estrangeira(
    tabela_origem='colaborador_treinamentos',    
    coluna_origem='idTreinamentos_Realizados',         
    tabela_destino='treinamentos',           
    coluna_destino='idTreinamentos_Realizados'         
)

# %% [markdown]
# ### *colaborador_empresa*

# %%
adicionar_chave_estrangeira(
    tabela_origem='colaborador_empresa',    
    coluna_origem='idColaborador',            
    tabela_destino='colaborador',               
    coluna_destino='idColaborador'            
)



adicionar_chave_estrangeira(
    tabela_origem='colaborador_empresa',   
    coluna_origem='Id_Empresa',         
    tabela_destino='empresa',           
    coluna_destino='Id_Empresa'        
)

# %% [markdown]
# ### *servico_competencias*

# %%
adicionar_chave_estrangeira(
    tabela_origem='servico_competencia',    
    coluna_origem='Id_Servico',             
    tabela_destino='servicos',               
    coluna_destino='Id_Servico'            
)


adicionar_chave_estrangeira(
    tabela_origem='servico_competencia',    
    coluna_origem='Id_Competencia',         
    tabela_destino='competencia',          
    coluna_destino='Id_Competencia'         
)

# %% [markdown]
# ### *empresa_servico*

# %%
adicionar_chave_estrangeira(
    tabela_origem='empresa_servico',   
    coluna_origem='Id_Empresa',             
    tabela_destino='empresa',              
    coluna_destino='Id_Empresa'            
)


adicionar_chave_estrangeira(
    tabela_origem='empresa_servico',    
    coluna_origem='Id_Servico',         
    tabela_destino='servicos',          
    coluna_destino='Id_Servico'         
)

# %% [markdown]
# ### *colaborador_photo*

# %%
adicionar_chave_estrangeira(
    tabela_origem='colaborador_photo',    
    coluna_origem='idColaborador',             
    tabela_destino='colaborador',               
    coluna_destino='idColaborador'             
)

# %% [markdown]
# ### *colaborador_competencia*

# %%
adicionar_chave_estrangeira(
    tabela_origem='colaborador_competencia',    
    coluna_origem='idColaborador',             
    tabela_destino='colaborador',               
    coluna_destino='idColaborador'            
)

adicionar_chave_estrangeira(
    tabela_origem='colaborador_competencia',    
    coluna_origem='Id_Competencia',         
    tabela_destino='competencia',           
    coluna_destino='Id_Competencia'        
)
