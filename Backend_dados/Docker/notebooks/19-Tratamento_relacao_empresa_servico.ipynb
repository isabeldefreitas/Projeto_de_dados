# %%
import pandas as pd
import os

# %%
import sys

sys.path.append('/app')

import importlib
import utils.conexao
importlib.reload(utils.conexao)# Importa a função e a variável do schema do módulo de conexão
from utils.conexao import get_dados_origem, SCHEMA_ORIGEM

# consulta
query = f'SELECT * FROM "{SCHEMA_ORIGEM}"."empresa_servico";'
df = get_dados_origem(query) # O nome da função para extrair dados da origem foi alterado

if df is not None:
    print("Extração concluída:")
    print(df.head())

# %%
df.info()

# %%
df.rename(columns={'empresa_id': 'Id_Empresa', 'servico_id' : 'Id_Servico'}, inplace=True)

# %%
# variável de ambiente para construir o caminho
caminho_base_arquivos = os.environ.get("CAMINHO_ARQUIVOS_CSV")
caminho_saida = os.path.join(caminho_base_arquivos, "dados_tratados_v2", "fato_Empresa_Servico.csv")

# variável caminho_saida
df.to_csv(caminho_saida, index=False)
